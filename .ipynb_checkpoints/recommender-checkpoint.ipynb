# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import *
import json
import numpy as np
import string
from datetime import *
import re

# %%
df = pd.read_json('all_movies.json').T

# %%
df.isna().sum()
# Out:
# title             16
# release           29
# popularity        16
# budget            16
# genres            16
# overview          16
# language          16
# votes             16
# status            16
# cast              16
# director          35
# screenwriter    1326
# producer         423
# music           2674
# dtype: int64

# %%
df.dropna(subset=['title', 'release'], inplace = True)

# %%
df.isna().sum()
# Out:
# title              0
# release            0
# popularity         0
# budget             0
# genres             0
# overview           0
# language           0
# votes              0
# status             0
# cast               0
# director          12
# screenwriter    1299
# producer         398
# music           2645
# dtype: int64

# %%
df[['release', 'votes']] = df[['release', 'votes']].astype('int64')
df[['popularity', 'budget']] = df[['popularity','budget']].astype('float64')

# %%
df = df[np.logical_not(df['director'].isna() & df['screenwriter'].isna() & df['producer'].isna() & df['music'].isna())]
#Filtered out movies whose director, screenwriter, producer and music director are all not available
df = df[np.logical_not(df['screenwriter'].isna() & df['producer'].isna() & df['music'].isna())]

# %%
df = df.dropna(subset=['director'])

# %%
df.groupby('status').count()
# Out:
#                  title  release  popularity  budget  genres  overview  \
# status
# Post Production      1        1           1       1       1         1
# Released          2856     2856        2856    2856    2856      2856
#
#                  language  votes  cast  director  screenwriter  producer  \
# status
# Post Production         1      1     1         1             0         1
# Released             2856   2856  2856      2856          1850      2748
#
#                  music
# status
# Post Production      0
# Released           504

# %%
df = df[df['status'] == 'Released']

# %%
df.groupby('status').count()
# Out:
#           title  release  popularity  budget  genres  overview  language  \
# status
# Released   2856     2856        2856    2856    2856      2856      2856
#
#           votes  cast  director  screenwriter  producer  music
# status
# Released   2856  2856      2856          1850      2748    504

# %%
df = df[df['status'] == 'Released']

# %%
def isEmpty(lst):
    if lst == []:
        return True
    return False

# %%
exists = []
for cast in df['cast']:
    exists.append(isEmpty(cast))
exists = np.logical_not(exists)
#Movies for which the cast has not been recorded

# %%
df = df[exists]

# %%
df.head()
# Out:
#                                              title  release  popularity  \
# All About Eve                        All About Eve     1950      18.255
# Sunset Boulevard                  Sunset Boulevard     1950      16.261
# In a Lonely Place                In a Lonely Place     1950       9.921
# A Streetcar Named Desire  A Streetcar Named Desire     1951      13.575
# An American in Paris          An American in Paris     1951      11.251
#
#                              budget                           genres  \
# All About Eve             1400000.0                          [Drama]
# Sunset Boulevard          1752000.0                          [Drama]
# In a Lonely Place               0.0              [Mystery, Thriller]
# A Streetcar Named Desire  1800000.0                          [Drama]
# An American in Paris      2723903.0  [Comedy, Drama, Music, Romance]
#
#                                                                    overview  \
# All About Eve             From the moment she glimpses her idol at the s...
# Sunset Boulevard          A hack screenwriter writes a screenplay for a ...
# In a Lonely Place         An aspiring actress begins to suspect that her...
# A Streetcar Named Desire  Disturbed Blanche DuBois moves in with her sis...
# An American in Paris      Jerry Mulligan is an exuberant American expatr...
#
#                          language  votes    status  \
# All About Eve                  en    879  Released
# Sunset Boulevard               en   1396  Released
# In a Lonely Place              en    269  Released
# A Streetcar Named Desire       en    744  Released
# An American in Paris           en    318  Released
#
#                                                                        cast  \
# All About Eve                    [Bette Davis, Anne Baxter, George Sanders]
# Sunset Boulevard          [William Holden, Gloria Swanson, Erich von Str...
# In a Lonely Place          [Humphrey Bogart, Gloria Grahame, Frank Lovejoy]
# A Streetcar Named Desire          [Vivien Leigh, Marlon Brando, Kim Hunter]
# An American in Paris               [Gene Kelly, Leslie Caron, Oscar Levant]
#
#                                       director          screenwriter  \
# All About Eve             Joseph L. Mankiewicz  Joseph L. Mankiewicz
# Sunset Boulevard                  Billy Wilder          Billy Wilder
# In a Lonely Place                 Nicholas Ray           Andrew Solt
# A Streetcar Named Desire            Elia Kazan    Tennessee Williams
# An American in Paris         Vincente Minnelli       Alan Jay Lerner
#
#                                     producer            music
# All About Eve               Darryl F. Zanuck  Urban Thielmann
# Sunset Boulevard            Charles Brackett             None
# In a Lonely Place                Robert Lord             None
# A Streetcar Named Desire  Charles K. Feldman             None
# An American in Paris            Arthur Freed  George Gershwin

# %%
def isDiff(a:str, b:str):
    table = str.maketrans("", "", string.punctuation)
    _a = a.translate(table)
    _b = b.translate(table)
    _a = re.sub(r' \(.*\)', '', _a)
    _b = re.sub(r' \(.*\)', '', _b)
    _a = re.sub(r' ?: ?.*','',_a)
    _b = re.sub(r' ?: ?.*', '', _b)
    return _a.lower() != _b.lower()

# %%
unequalid = []
for idx, n in df.iterrows():
    if isDiff(n['title'], idx):
        unequalid.append(idx)

# %%
df.loc[unequalid]
# Out:
#                                                                title  release  \
# Rashomon                                          Tombstone Rashomon     2017
# Seven Samurai                  Seven Samurai: Origins and Influences     2006
# Wild Strawberries                 Frisky Summer 3: Wild Strawberries     1998
# The Leopard                                          The Leopard Man     1943
# Masculin Feminin                                    Masculin Féminin     1966
# ...                                                              ...      ...
# Birds of Prey      Birds of Prey (and the Fantabulous Emancipatio...     2020
# End of Sentence                             Period. End of Sentence.     2018
# Bull                                                     Raging Bull     1980
# The Truth                                      Nothing But the Truth     2008
# Judy & Punch                                                    Judy     2019
#
#                    popularity      budget                       genres  \
# Rashomon                4.100         0.0                    [Western]
# Seven Samurai           0.600         0.0                [Documentary]
# Wild Strawberries       0.600         0.0                           []
# The Leopard             6.335         0.0  [Mystery, Horror, Thriller]
# Masculin Feminin        9.646         0.0             [Drama, Romance]
# ...                       ...         ...                          ...
# Birds of Prey          89.685  75000000.0      [Action, Crime, Comedy]
# End of Sentence         9.978         0.0                [Documentary]
# Bull                   22.305  18000000.0                      [Drama]
# The Truth              18.351  11500000.0            [Drama, Thriller]
